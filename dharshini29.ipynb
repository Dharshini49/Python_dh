# %%
#slicing operator
list=[1,2,3,4,5]
list[-2:] #last two
# Out:
# [4, 5]

# %%
list[:2] #first two
# Out:
# [1, 2]

# %%
list[-3] #last 3rd
# Out:
# 3

# %%
list[2:] # 3rd to last
# Out:
# [3, 4, 5]

# %%
myfav=['cake','pizza','stew']
ffav1=myfav[:] #copy by value
ffav2=myfav #copy by reference

# %%
ffav1
# Out:
# ['cake', 'pizza', 'stew']

# %%
ffav2
# Out:
# ['cake', 'pizza', 'stew']

# %%
myfav.append('porridge') #append function

# %%
myfav
# Out:
# ['cake', 'pizza', 'stew', 'porridge']

# %%
ffav2
# Out:
# ['cake', 'pizza', 'stew', 'porridge']

# %%
myfav=['cake', 'pizza', 'stew', 'porridge','soup'] #rewriting the list
ffav2
# Out:
# ['cake', 'pizza', 'stew', 'porridge']

# %%
myfav
# Out:
# ['cake', 'pizza', 'stew', 'porridge', 'soup']

# %%
ffav1
# Out:
# ['cake', 'pizza', 'stew']

# %%
ffav2
# Out:
# ['cake', 'pizza', 'stew', 'porridge']

# %%
ffav3=myfav.copy() #copy function

# %%
ffav3
# Out:
# ['cake', 'pizza', 'stew', 'porridge', 'soup']

# %%
for r in myfav[:]:
    print(r.title())
# Out:
# Cake
# Pizza
# Stew
# Porridge
# Soup

# %%
t=(500,100)
print(t[1])
# Out:
# 100

# %%
t[0]
# Out:
# 500

# %%
for i in t:
    print(t)
# Out:
# (500, 100)
# (500, 100)

# %%
t[1]=-50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 t[1]=-50
#
# TypeError: 'tuple' object does not support item assignment

# %%
#dictionary
std1={'regno':'22mid0132',
      'prg':'MID',
      'cgpa':9.4, # no need quotes for numeric values
      'attendance':100 }
