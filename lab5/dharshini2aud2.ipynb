# %%
                                                  '''  CSI3007-Advanced Python Programming
                                                            Lab-5 (02/08/2025)
                                                        22MID0132 - DHARSHINI R '''
# Out:
# '  CSI3007-Advanced Python Programming\n          Lab-5 (02/08/2025)\n      22MID0132 - DHARSHINI R '

# %%
# importing our own package and running it

# %%
# 16. Storing Your Functions in Modules
import myfile
# Out:
# pepperoni pizza
# mushrooms pizza
# cheese pizza
# {'age': 20, 'branch': 'MID', 'year': 4, 'fname': 'dharshini', 'lname': 'r'}

# %%
# 17. Importing Specific Functions
import myfile 
from myfile import fullname
fullname('dharshini','r')
# Out:
# 'Dharshini R'

# %%
# 18. Give a Function an Alias using 'as'
import myfile 
from myfile import fullname as fn
fn('karunya','lakshmi')
# Out:
# 'Karunya Lakshmi'

# %%
# 19. Give a Module an Alias uisng 'as'
import myfile as mf

# %%
# 20. Importing All Functions in a Module
from myfile import *
