# %% [markdown]
# # Advanced Python --> Lab-12
# # 22MID0132 -- DHARSHINI R

# %%
import pandas as pd

# %%
# reading csv using pandas

# %%
data = pd.read_csv('C:/Users/dhars/Downloads/people-100.csv')

# %%
# Extracting content of the dataframe

# %%
data.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %%
# Creating a new row

# %%
new_data = {'Index':101,
            'User Id':'A31Her3c201ef58',
            'First Name':'dharshini',
            'Last Name':'R',
            'Sex':'Female',
            'Email':'dharshini@example.com',
            'Phone':9876543210,
            'Date of birth':'2022-06-18',
            'Job Title':'Data Scientist'
           }

# %%
# appending the new row to the dataframe

# %%
data.loc[3]=new_data

# %%
data.head() # to see the changes made
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3    101  A31Her3c201ef58  dharshini         R  Female
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3       dharshini@example.com              9876543210    2022-06-18
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3      Data Scientist
# 4  Veterinary surgeon

# %%
# adding chunk of row

# %%
new_data2 = {
    'Index': [101, 102],
    'User Id': ['A31Her3c201ef58', 'f90cD3E78f2A9b9'],
    'First Name': ['dharshini', 'agnes'],
    'Last Name': ['R', 'Rachel'],
    'Sex': ['Female', 'Female'],
    'Email': ['dharshini@example.com', 'agnesrachel@example.com'],
    'Phone': [9876543210, '0123456789'],  
    'Date of birth': ['2022-06-18', '2004-09-01'],
    'Job Title': ['Data Scientist', 'Developer']
}

# %%
new_df = pd.DataFrame(new_data2)

# %%
file_path = 'data.csv' 
new_df.to_csv(file_path, mode='a', header=False, index=False)

# %%
# working chunk by chunk in th csv

# %%
i = pd.read_csv('people-100.csv', iterator=True, chunksize=50)
new=[]
for chunk in i:
    for index,row in chunk.iterrows():
        print(row)
    new.append(chunk)
df=pd.concat(new)
# Out:
# Index                                 1
# User Id                 88F7B33d2bcf9f5
# First Name                       Shelby
# Last Name                       Terrell
# Sex                                Male
# Email              elijah57@example.net
# Phone            001-084-906-7849x73518
# Date of birth                1945-10-26
# Job Title               Games developer
# Name: 0, dtype: object
# Index                                2
# User Id                f90cD3E76f1A9b9
# First Name                     Phillip
# Last Name                      Summers
# Sex                             Female
# Email            bethany14@example.com
# Phone                214.112.6044x4913
# Date of birth               1910-03-24
# Job Title               Phytotherapist
# Name: 1, dtype: object
# Index                                3
# User Id                DbeAb8CcdfeFC2c
# First Name                    Kristine
# Last Name                       Travis
# ...
